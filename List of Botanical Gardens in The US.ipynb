# %%
import pandas as pd
import pymongo
url= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_the_United_States'

# %%
tables=pd.read_html(url)
tables[0]
# Out:
#                          Name  Image                     Affiliation  \
# 0     Alaska Botanical Garden    NaN                             NaN
# 1  Georgeson Botanical Garden    NaN  University of Alaska Fairbanks
# 2      Jensen-Olson Arboretum    NaN      City and Borough of Juneau
#
#         City
# 0  Anchorage
# 1  Fairbanks
# 2     Juneau

# %%
alaska= tables[0]
alaska_d= pd.DataFrame(alaska)
alaska_df= alaska_d.drop(columns= 'Image')
alaska_df['State'] = 'Alaska'
alaska_df
# Out:
#                          Name                     Affiliation       City  \
# 0     Alaska Botanical Garden                             NaN  Anchorage
# 1  Georgeson Botanical Garden  University of Alaska Fairbanks  Fairbanks
# 2      Jensen-Olson Arboretum      City and Borough of Juneau     Juneau
#
#     State
# 0  Alaska
# 1  Alaska
# 2  Alaska

# %%
arizona= tables[1]
arizona_d= pd.DataFrame(arizona)
arizona_df= arizona_d.drop(columns= "Image")
arizona_df['State'] = 'Arizona'
arizona_df
# Out:
#                                            Name               Affiliation  \
# 0         Arboretum at Arizona State University  Arizona State University
# 1                    The Arboretum at Flagstaff                       NaN
# 2               Arizona Cactus Botanical Garden                       NaN
# 3                  Arizona-Sonora Desert Museum                       NaN
# 4           Boyce Thompson Arboretum State Park                       NaN
# 5                       Desert Botanical Garden                       NaN
# 6                     Forever Ranch and Gardens                       NaN
# 7   Navajo Nation Zoological and Botanical Park             Navajo Nation
# 8                              Tohono Chul Park                       NaN
# 9                      Tucson Botanical Gardens                       NaN
# 10       University of Arizona Campus Arboretum     University of Arizona
#
#            City    State
# 0         Tempe  Arizona
# 1     Flagstaff  Arizona
# ...

# %%
arkansas=tables[2]
arkansas_d= pd.DataFrame(arkansas)
arkansas_df= arkansas_d.drop(columns= "Image")
arkansas_df['State'] = 'Arkansas'
arkansas_df
# Out:
#                              Name  \
# 0              Arkansas Arboretum
# 1    Blue Springs Heritage Center
# 2  Botanical Garden of the Ozarks
# 3         Garvan Woodland Gardens
# 4        South Arkansas Arboretum
#
#                                       Affiliation            City     State
# 0                    Pinnacle Mountain State Park     Little Rock  Arkansas
# 1                                             NaN  Eureka Springs  Arkansas
# 2                                             NaN    Fayetteville  Arkansas
# 3  University of Arkansas Division of Agriculture     Hot Springs  Arkansas
# 4                South Arkansas Community College       El Dorado  Arkansas

# %%
colorado= tables[3]
colorado_= pd.DataFrame(colorado)
colorado_df= colorado_.drop(columns= "Image")
colorado_df['State']= 'Colorado'
colorado_df
# Out:
#                                  Name           Affiliation  \
# 0          Chester M. Alter Arboretum  University of Denver
# 1                   Andrews Arboretum                   NaN
# 2              Denver Botanic Gardens                   NaN
# 3           Betty Ford Alpine Gardens                   NaN
# 4                      Hudson Gardens                   NaN
# 5            Montrose Botanic Gardens                   NaN
# 6           Shambhala Botanic Gardens                   NaN
# 7  Western Colorado Botanical Gardens                   NaN
# 8            Yampa River Botanic Park                   NaN
#
#                 City     State
# 0             Denver  Colorado
# 1            Boulder  Colorado
# 2             Denver  Colorado
# 3               Vail  Colorado
# 4          Littleton  Colorado
# 5           Montrose  Colorado
# 6  Red Feather Lakes  Colorado
# 7     Grand Junction  Colorado
# 8  Steamboat Springs  Colorado

# %%
connecticut= tables[4]
connecticut_df= pd.DataFrame(connecticut)
connecticut_df['State']= 'Connecticut'
connecticut_df= connecticut_df.drop(columns= "Image")
connecticut_df
# Out:
#                                                  Name  \
# 0                      Bartlett Arboretum and Gardens
# 1                       Connecticut College Arboretum
# 2                   Dinosaur State Park and Arboretum
# 3                           Edgerton Park Conservancy
# 4   EEB Biodiversity Education & Research Greenhouses
# 5                        Harkness Memorial State Park
# 6                           Hartford Botanical Garden
# 7                                 Highstead Arboretum
# 8                              Marsh Botanical Garden
# 9                            New Canaan Nature Center
# 10                     Richard Haley Wildlife Gardens
#
#                   Affiliation        City        State
# 0                         NaN    Stamford  Connecticut
# 1         Connecticut College  New London  Connecticut
# 2                         NaN  Rocky Hill  Connecticut
# 3                         NaN   New Haven  Connecticut
# ...

# %%
delaware= tables[5]
delaware_df= pd.DataFrame(delaware)
delaware_df= delaware_df.drop(columns= "Image")
delaware_df['State']= 'Delaware'
delaware_df
# Out:
#                                      Name             Affiliation        City  \
# 0        Delaware Center for Horticulture                     NaN  Wilmington
# 1               Hagley Museum and Library                     NaN  Greenville
# 2                         Mt. Cuba Center                     NaN   Hockessin
# 3             Nemours Mansion and Gardens                     NaN  Wilmington
# 4  University of Delaware Botanic Gardens  University of Delaware      Newark
# 5           Winterthur Museum and Grounds                     NaN  Winterthur
#
#       State
# 0  Delaware
# 1  Delaware
# 2  Delaware
# 3  Delaware
# 4  Delaware
# 5  Delaware

# %%
district_of_columbia= tables[6]
district_of_columbia_df= pd.DataFrame(district_of_columbia)
district_of_columbia_df= district_of_columbia_df.drop(columns= "Image")
district_of_columbia_df['State']= 'District of Coloumbia'
district_of_columbia_df
# Out:
#                                         Name                    Affiliation  \
# 0  American University Arboretum and Gardens            American University
# 1                             Dumbarton Oaks             Harvard University
# 2               Franciscan Monastery gardens                            NaN
# 3                  Hillwood Museum & Gardens                            NaN
# 4        Kenilworth Park and Aquatic Gardens          National Park Service
# 5                        Smithsonian Gardens        Smithsonian Institution
# 6                                Tudor Place                            NaN
# 7               United States Botanic Garden          United States Capitol
# 8           United States National Arboretum  Agricultural Research Service
#
#          City                  State
# 0  Washington  District of Coloumbia
# 1  Washington  District of Coloumbia
# 2  Washington  District of Coloumbia
# 3  Washington  District of Coloumbia
# ...

# %%
georgia= tables[7]
georgia_df= pd.DataFrame(georgia)
georgia_df= georgia_df.drop(columns= "Image")
georgia_df['State']= 'Georgia'
georgia_df
# Out:
#                                             Name  \
# 0                       Atlanta Botanical Garden
# 1               Waddell Barnes Botanical Gardens
# 2                               Callaway Gardens
# 3              Coastal Georgia Botanical Gardens
# 4               Coastal Plain Research Arboretum
# 5                     Columbus Botanical Gardens
# 6                        Fernbank Science Center
# 7   Georgia Golf Hall of Fame's Botanical Garden
# 8     Georgia Perimeter College Botanical Garden
# 9              Georgia Southern Botanical Garden
# 10             Fred Hamilton Rhododendron Garden
# 11                  Hart County Botanical Garden
# 12                            Lockerly Arboretum
# 13                           Massee Lane Gardens
# 14         The State Botanical Garden of Georgia
# 15                         Thompson Mills Forest
# 16        University of Georgia Campus Arboretum
# 17                       Vines Botanical Gardens
# ...

# %%
guam= tables[8]
guam_df= pd.DataFrame(guam)
guam_df['State']= 'Guam'
guam_df= guam_df.drop(columns= "Image")
guam_df
# Out:
#                                              Name  Affiliation   City State
# 0  Guam Zoological, Botanical & Marine Gardens[1]          NaN  Tumon  Guam

# %%
idaho= tables[9]
idaho_df= pd.DataFrame(idaho)
idaho_df['State']= 'Idaho'
idaho_df=idaho_df.drop(columns= "Image")
idaho_df
# Out:
#                                                 Name             Affiliation  \
# 0                                     Arboretum Park                     NaN
# 1                             Idaho Botanical Garden                     NaN
# 2                              Idaho State Arboretum  Idaho State University
# 3                          Sawtooth Botanical Garden                     NaN
# 4  University of Idaho Arboretum and Botanical Ga...     University of Idaho
#
#         City  State
# 0      Eagle  Idaho
# 1      Boise  Idaho
# 2  Pocatello  Idaho
# 3    Ketchum  Idaho
# 4     Moscow  Idaho

# %%
indiana= tables[10]
indiana_df= pd.DataFrame(indiana)
indiana_df['State']= 'Indiana'
indiana_df= indiana_df.drop(columns= "Image")
indiana_df
# Out:
#                                                  Name  \
# 0                                       Christy Woods
# 1                       Jerry E. Clegg Botanic Garden
# 2          Foellinger-Freimann Botanical Conservatory
# 3       Garfield Park Conservatory and Sunken Gardens
# 4                              Greenfield Herb Garden
# 5                                     Hayes Arboretum
# 6                                     Holcomb Gardens
# 7   Huntington University Arboretum and Botanical ...
# 8                        Indiana University Arboretum
# 9                             Lilly House and Gardens
# 10                          Potawatomi Conservatories
# 11             Purdue University Horticulture Gardens
# 12                      Taltree Arboretum and Gardens
# 13         Wheeler Orchid Collection and Species Bank
# 14                          Wellfield Botanic Gardens
# 15                                White River Gardens
#
# ...

# %%
iowa= tables[11]
iowa_df= pd.DataFrame(iowa)
iowa_df['State']= 'Iowa'
iowa_df= iowa_df.drop(columns= "Image")
iowa_df
# Out:
#                                                  Name  \
# 0                               Bickelhaupt Arboretum
# 1                             Arie den Boer Arboretum
# 2                                   Brenton Arboretum
# 3                               Buxton Park Arboretum
# 4            Cedar Valley Arboretum & Botanic Gardens
# 5                                          Crapo Park
# 6             Dubuque Arboretum and Botanical Gardens
# 7                    Forest Park Museum and Arboretum
# 8     Frontier Organic Research Farm Botanical Garden
# 9                 Greater Des Moines Botanical Garden
# 10                                     Iowa Arboretum
# 11              Lilac Arboretum and Children's Forest
# 12                                Muscatine Arboretum
# 13             Newton Arboretum and Botanical Gardens
# 14                                     Reiman Gardens
# 15                                Stampe Lilac Garden
# ...

# %%
kansas= tables[12]
kansas_df= pd.DataFrame(kansas)
kansas_df= kansas_df.drop(columns= "Image")
kansas_df["state"]= 'Kansas'
kansas_df
# Out:
#                                              Name              Affiliation  \
# 0                              Bartlett Arboretum                      NaN
# 1                   Botanica, The Wichita Gardens                      NaN
# 2                    Dyck Arboretum of the Plains                      NaN
# 3              International Forest of Friendship                      NaN
# 4                      Kansas Landscape Arboretum                      NaN
# 5                 Kansas State University Gardens  Kansas State University
# 6   Overland Park Arboretum and Botanical Gardens    Overland Park, Kansas
# 7                               Parsons Arboretum                      NaN
# 8      Reinisch Rose Garden and Doran Rock Garden                      NaN
# 9             Sedgwick County Extension Arboretum                      NaN
# 10              Ward-Meade Park Botanical Gardens                      NaN
#
#                City   state
# 0      Belle Plaine  Kansas
# ...

# %%
kentucky= tables[13]
kentucky_df= pd.DataFrame(kentucky)
kentucky_df=kentucky_df.drop(columns="Image")
kentucky_df['State']= 'Kentucky'
kentucky_df
# Out:
#                                                  Name             Affiliation  \
# 0                                     Baker Arboretum                     NaN
# 1              Bernheim Arboretum and Research Forest                     NaN
# 2                              Boone County Arboretum                     NaN
# 3                                  Cave Hill Cemetery                     NaN
# 4                       Kentucky Horse Park Arboretum                     NaN
# 5                                  Lexington Cemetery                     NaN
# 6   University of Kentucky/Lexington-Fayette Urban...  University of Kentucky
# 7   University of Kentucky Research and Education ...  University of Kentucky
# 8                       Nannine Clay Wallis Arboretum                     NaN
# 9                        Waterfront Botanical Gardens                     NaN
# 10                  Western Kentucky Botanical Garden                     NaN
# ...

# %%
louisiana= tables[14]
louisiana_df= pd.DataFrame(louisiana)
louisiana_df=louisiana_df.drop(columns='Image')
louisiana_df['State']= 'Louisiana'
louisiana_df
# Out:
#                                                Name  \
# 0                     Biedenharn Museum and Gardens
# 1   Laurens Henry Cohn Sr. Memorial Plant Arboretum
# 2           The Gardens of the American Rose Center
# 3                         Hodges Gardens State Park
# 4                 Independence Park Botanic Gardens
# 5                                    Jungle Gardens
# 6                      Longue Vue House and Gardens
# 7                         Louisiana State Arboretum
# 8               Louisiana Tech University Arboretum
# 9                      LSU AgCenter Botanic Gardens
# 10                            LSU Hilltop Arboretum
# 11                     New Orleans Botanical Garden
#
#                    Affiliation          City      State
# 0                          NaN        Monroe  Louisiana
# 1                          NaN   Baton Rouge  Louisiana
# 2                          NaN    Shreveport  Louisiana
# 3                          NaN          Many  Louisiana
# ...

# %%
maine= tables[15]
maine_df= pd.DataFrame(maine)
maine_df=maine_df.drop(columns= 'Image')
maine_df['State']="Maine"
maine_df
# Out:
#                                              Name  \
# 0                      Carnegie Science Arboretum
# 1                 Coastal Maine Botanical Gardens
# 2                    Ecotat Gardens and Arboretum
# 3                 Fay Hyland Botanical Plantation
# 4   Harvey Butler Memorial Rhododendron Sanctuary
# 5    Lyle E. Littlefield Ornamentals Trial Garden
# 6                            Longfellow Arboretum
# 7                               Perkins Arboretum
# 8                              Shoreway Arboretum
# 9                          Wild Gardens of Acadia
# 10                                Viles Arboretum
#
#                          Affiliation                 City  State
# 0                      Bates College             Lewiston  Maine
# 1                                NaN             Boothbay  Maine
# 2                                NaN               Hermon  Maine
# 3                University of Maine                Orono  Maine
# ...

# %%
maryland= tables[16]
maryland_df= pd.DataFrame(maryland)
maryland_df= maryland_df.drop(columns='Image')
maryland_df['State']='Maryland'
maryland_df
# Out:
#                                                 Name  \
# 0                                   Adkins Arboretum
# 1                                  Brookside Gardens
# 2                                  Cylburn Arboretum
# 3                   Historic London Town and Gardens
# 4                              Ladew Topiary Gardens
# 5                                  McCrillis Gardens
# 6  Howard Peters Rawlings Conservatory and Botani...
# 7                     Salisbury University Arboretum
# 8                        Helen Avalynne Tawes Garden
# 9  University of Maryland Arboretum & Botanical G...
#
#                                          Affiliation          City     State
# 0                                Tuckahoe State Park       Ridgely  Maryland
# 1  Maryland-National Capital Park and Planning Co...       Wheaton  Maryland
# 2  City of Baltimore Recreation and Parks Department     Baltimore  Maryland
# ...

# %%
michigan= tables[17]
michigan_df= pd.DataFrame(michigan)
michigan_df= michigan_df.drop(columns='Image')
michigan_df["State"]='Michigan'
michigan_df
# Out:
#                                               Name                Affiliation  \
# 0                      W. J. Beal Botanical Garden  Michigan State University
# 1                                      Dow Gardens                        NaN
# 2    Fernwood Botanical Garden and Nature Preserve                        NaN
# 3                              Hidden Lake Gardens  Michigan State University
# 4                                  Leila Arboretum                        NaN
# 5                         MacArthur Park Arboretum                        NaN
# 6                       Matthaei Botanical Gardens     University of Michigan
# 7         Frederik Meijer Gardens & Sculpture Park                        NaN
# 8   Michigan State University Horticulture Gardens  Michigan State University
# 9                                Nichols Arboretum     University of Michigan
# 10                               Slayton Arboretum          Hillsdale College
# ...

# %%
minnesota= tables[18]
minnesota_df= pd.DataFrame(minnesota)
minnesota_df= minnesota_df.drop(columns= 'Image')
minnesota_df["State"]= 'Minnesota'
minnesota_df
# Out:
#                                                  Name  \
# 0                                    Bergeson Gardens
# 1   Eloise Butler Wildflower Garden and Bird Sanct...
# 2                  Carleton College Cowling Arboretum
# 3                      Como Park Zoo and Conservatory
# 4                    Leif Erickson Park & Rose Garden
# 5                                  Linnaeus Arboretum
# 6                                Lyndale Park Gardens
# 7                       Minnesota Landscape Arboretum
# 8               Munsinger Gardens and Clemens Gardens
# 9                                 Northland Arboretum
# 10                             Olcott Park Greenhouse
# 11                             Saint John's Arboretum
#
#                                           Affiliation          City      State
# 0                                    Bergeson Nursery       Fertile  Minnesota
# 1                                 Theodore Wirth Park   Minneapolis  Minnesota
# ...

# %%
mississippi= tables[19]
mississippi_df=pd.DataFrame(mississippi)
mississippi_df= mississippi_df.drop(columns= 'Image')
mississippi_df["State"]= 'Mississippi'
mississippi_df
# Out:
#                                         Name                   Affiliation  \
# 0                           Crosby Arboretum  Mississippi State University
# 1     Forestry Sciences Laboratory Arboretum                           NaN
# 2  Jackson State University Botanical Garden                           NaN
# 3                          Simmons Arboretum                           NaN
#
#          City        State
# 0    Picayune  Mississippi
# 1  Starkville  Mississippi
# 2     Jackson  Mississippi
# 3     Madison  Mississippi

# %%
missouri= tables[20]
missouri_df= pd.DataFrame(missouri)
missouri_df= missouri_df.drop(columns= 'Image')
missouri_df["State"]= "Missouri"
missouri_df
# Out:
#                                                 Name  \
# 0          Ewing and Muriel Kauffman Memorial Garden
# 1                                McAlester Arboretum
# 2                          Missouri Botanical Garden
# 3                           Missouri State Arboretum
# 4                              Mizzou Botanic Garden
# 5                                     Powell Gardens
# 6                                           Seiwa-en
# 7                                Shaw Nature Reserve
# 8  Springfield-Greene County Botanical Center and...
#
#                            Affiliation         City     State
# 0     Ewing Marion Kauffman Foundation  Kansas City  Missouri
# 1               University of Missouri     Columbia  Missouri
# 2                                  NaN    St. Louis  Missouri
# 3  Northwest Missouri State University    Maryville  Missouri
# 4               University of Missouri     Columbia  Missouri
# ...

# %%
montana= tables[21]
montana_df= pd.DataFrame(montana)
montana_df= montana_df.drop(columns= 'Image')
montana_df= montana_df.drop(columns= 'Unnamed: 4')
montana_df['State']= 'Montana'
montana_df
# Out:
#                                   Name               Affiliation  \
# 0          Official State Arboretum[2]     University of Montana
# 1                       Gatiss Gardens                       NaN
# 2        International Larix Arboretum                       NaN
# 3        Montana Arboretum and Gardens  Montana State University
# 4    Tizer Botanic Gardens & Arboretum                       NaN
# 5      Botanical Gardens of ZooMontana                       NaN
# 6  Yellowstone Arboretum of ZooMontana                       NaN
#
#              City    State
# 0        Missoula  Montana
# 1       Kalispell  Montana
# 2    Hungry Horse  Montana
# 3         Bozeman  Montana
# 4  Jefferson City  Montana
# 5        Billings  Montana
# 6        Billings  Montana

# %%
nebraska= tables[22]
nebraska_df= pd.DataFrame(nebraska)
nebraska_df=nebraska_df.drop(columns= 'Image')
nebraska_df['State']= 'Nebraska'
nebraska_df
# Out:
#                                                Name  \
# 0                              Alice Abel Arboretum
# 1   Arbor Lodge State Historical Park and Arboretum
# 2                 Doane College Osterhout Arboretum
# 3                         Governor Furnas Arboretum
# 4                             Gilman Park Arboretum
# 5                 Itha T. Krumme Memorial Arboretum
# 6       Lauritzen Gardens, Omaha's Botanical Center
# 7                                 Maxwell Arboretum
# 8                  D. A. Murphy Panhandle Arboretum
# 9                      Nebraska Statewide Arboretum
# 10                   Norris Forest School Arboretum
# 11                        Northfield Park Arboretum
# 12                        State Fair Park Arboretum
# 13                       Joshua C. Turner Arboretum
# 14                    Wayne State College Arboretum
#
#                      Affiliation           City     State
# 0   Nebraska Wesleyan University        Lincoln  Nebraska
# ...

# %%
nevada= tables[23]
nevada_df= pd.DataFrame(nevada)
nevada_df= nevada_df.drop(columns='Image')
nevada_df["State"]="Nevada"
nevada_df
# Out:
#                                             Name           Affiliation  \
# 0                    Alan Bible Botanical Garden                   NaN
# 1                Ethel M Botanical Cactus Garden                   NaN
# 2  The Gardens at the Las Vegas Springs Preserve                   NaN
# 3   Wilbur D. May Arboretum and Botanical Garden                   NaN
# 4      Southern Nevada Zoological-Botanical Park                   NaN
# 5           University of Nevada, Reno Arboretum  University of Nevada
# 6                                 UNLV Arboretum  University of Nevada
#
#            City   State
# 0  Boulder City  Nevada
# 1     Henderson  Nevada
# 2     Las Vegas  Nevada
# 3          Reno  Nevada
# 4     Las Vegas  Nevada
# 5          Reno  Nevada
# 6      Paradise  Nevada

# %%
new_hampshire= tables[24]
new_hampshire_df= pd.DataFrame(new_hampshire)
new_hampshire_df=new_hampshire_df.drop(columns='Image')
new_hampshire_df["State"]= 'New Hampshire'
new_hampshire_df
# Out:
#                                  Name  Affiliation           City  \
# 0                     Bedrock Gardens          NaN            Lee
# 1                      Fuller Gardens          NaN  North Hampton
# 2                     Nathan's Garden          NaN        Hanover
# 3             Rhododendron State Park          NaN    Fitzwilliam
# 4  Rockingham County Botanical Garden          NaN      Brentwood
#
#            State
# 0  New Hampshire
# 1  New Hampshire
# 2  New Hampshire
# 3  New Hampshire
# 4  New Hampshire

# %%
new_mexico= tables[25]
new_mexico_df=pd.DataFrame(new_mexico)
new_mexico_df=new_mexico_df.drop(columns= 'Image')
new_mexico_df["State"]='New Mexico'
new_mexico_df
# Out:
#                                        Name                  Affiliation  \
# 0               Albuquerque Biological Park                          NaN
# 1              Fabian Garcia Science Center  New Mexico State University
# 2  Living Desert Zoo and Gardens State Park                          NaN
# 3                 Rio Grande Botanic Garden                          NaN
# 4                 Santa Fe Botanical Garden                          NaN
# 5        University of New Mexico Arboretum     University of New Mexico
#
#           City       State
# 0  Albuquerque  New Mexico
# 1   Las Cruces  New Mexico
# 2     Carlsbad  New Mexico
# 3  Albuquerque  New Mexico
# 4     Santa Fe  New Mexico
# 5  Albuquerque  New Mexico

# %%
north_dakota= tables[26]
north_dakota_df= pd.DataFrame(north_dakota)
north_dakota_df=north_dakota_df.drop(columns='Image')
north_dakota_df['State']=' North Dakota'
north_dakota_df
# Out:
#                                      Name  Affiliation            City  \
# 0        Berthold Public School Arboretum          NaN        Berthold
# 1             Denbigh Experimental Forest          NaN          Towner
# 2     Fort Stevenson State Park Arboretum          NaN        Garrison
# 3     Gunlogson Arboretum Nature Preserve          NaN        Cavalier
# 4              International Peace Garden          NaN  Rolette County
# 5                          Myra Arboretum          NaN        Larimore
# 6  Northern Plains Botanic Garden Society          NaN           Fargo
#
#            State
# 0   North Dakota
# 1   North Dakota
# 2   North Dakota
# 3   North Dakota
# 4   North Dakota
# 5   North Dakota
# 6   North Dakota

# %%
oklahoma= tables[27]
oklahoma_df= pd.DataFrame(oklahoma)
oklahoma_df=oklahoma_df.drop(columns='Image')
oklahoma_df['State']= 'Oklahoma'
oklahoma_df
# Out:
#                                                  Name  \
# 0                     Cann Memorial Botanical Gardens
# 1             Cedarvale Botanic Garden and Restaurant
# 2                                    Garrard Ardeneum
# 3                          Hambrick Botanical Gardens
# 4                                  Honor Heights Park
# 5       Washington Irving Memorial Park and Arboretum
# 6                   Kerr Arboretum and Botanical Area
# 7                                  Lendonwood Gardens
# 8                                  Jo Allyn Lowe Park
# 9                         Midwest City Hall Arboretum
# 10                                 Morrison Arboretum
# 11                           Myriad Botanical Gardens
# 12     North Central Oklahoma Cactus Botanical Garden
# 13      North Oklahoma Botanical Garden and Arboretum
# 14            Oklahoma Botanical Garden and Arboretum
# 15  Oklahoma City Zoological Park and Botanical Ga...
# ...

# %%
puerto_rico= tables[28]
puerto_rico_df= pd.DataFrame(puerto_rico)
puerto_rico_df=puerto_rico_df.drop(columns='Image')
puerto_rico_df['State']= 'Puerto Rico'
puerto_rico_df
# Out:
#                         Name                Affiliation      City        State
# 0  San Juan Botanical Garden  University of Puerto Rico  San Juan  Puerto Rico

# %%
rhode_island= tables[29]
rhode_island_df= pd.DataFrame(rhode_island)
rhode_island_df= rhode_island_df.drop(columns='Image')
rhode_island_df["State"]= "Rhode Island"
rhode_island_df
# Out:
#                                                 Name  \
# 0          Blithewold Mansion, Gardens and Arboretum
# 1  University of Rhode Island Botanical Gardens a...
# 2                                        Wilcox Park
#
#                   Affiliation      City         State
# 0                         NaN   Bristol  Rhode Island
# 1  University of Rhode Island  Kingston  Rhode Island
# 2                         NaN  Westerly  Rhode Island

# %%
south_dakota= tables[30]
south_dakota_df= pd.DataFrame(south_dakota)
south_dakota_df=south_dakota_df.drop(columns="Image")
south_dakota_df['State']= 'South Dakota'
south_dakota_df
# Out:
#                                          Name                    Affiliation  \
# 0                           Kuhnert Arboretum                            NaN
# 1  McCrory Gardens and South Dakota Arboretum  South Dakota State University
# 2                             Reptile Gardens                            NaN
# 3                    Mary Jo Wegner Arboretum                            NaN
#
#           City         State
# 0     Aberdeen  South Dakota
# 1    Brookings  South Dakota
# 2   Rapid City  South Dakota
# 3  Sioux Falls  South Dakota

# %%
tennessee= tables[31]
tennessee_df= pd.DataFrame(tennessee)
tennessee_df= tennessee_df.drop(columns='Image')
tennessee_df['State']= 'Tennessee'
tennessee_df
# Out:
#                                                 Name  \
# 0                             Belle Meade Plantation
# 1                               Bonny Oaks Arboretum
# 2                             Daniel Boone Arboretum
# 3                      Burchfiel Grove and Arboretum
# 4       Cheekwood Botanical Garden and Museum of Art
# 5                Cherokee Arboretum at Audubon Acres
# 6                           Cherokee Trail Arboretum
# 7                         Clarksville City Arboretum
# 8                Gerald D. Coorts Memorial Arboretum
# 9                 Deerwood Arboretum and Nature Area
# 10                         Dixon Gallery and Gardens
# 11         East Tennessee State University Arboretum
# 12                               Hermitage Arboretum
# 13                    Interstate Packaging Arboretum
# 14          Knoxville Botanical Garden and Arboretum
# 15                            Memphis Botanic Garden
# 16                                    Oaklawn Garden
# ...

# %%
texas= tables[32]
texas_df= pd.DataFrame(texas)
texas_df= texas_df.drop(columns='Image')
texas_df['State']= 'Texas'
texas_df
# Out:
#                                                  Name  \
# 0                           Amarillo Botanical Garden
# 1   D. A. "Andy" Anderson Arboretum (Originally na...
# 2                          Beaumont Botanical Gardens
# 3                            Carleen Bright Arboretum
# 4   Chihuahuan Desert Nature Center and Botanical ...
# 5               Dallas Arboretum and Botanical Garden
# 6          East Texas Arboretum and Botanical Society
# 7                           Fort Worth Botanic Garden
# 8                 Houston Arboretum and Nature Center
# 9                       John Henry Kirby State Forest
# 10                Lady Bird Johnson Wildflower Center
# 11                         Lubbock Memorial Arboretum
# 12                           Lynn R. Lowrey Arboretum
# 13                                     Mast Arboretum
# 14                          McAllen Botanical Gardens
# 15               Mercer Arboretum and Botanic Gardens
# ...

# %%
virgin_islands= tables[33]
virgin_islands_df= pd.DataFrame(virgin_islands)
virgin_islands_df=virgin_islands_df.drop(columns='Image')
virgin_islands_df['State']=' Virgin Islands'
virgin_islands_df
# Out:
#                                   Name  Affiliation          City  \
# 0                 Magens Bay Arboretum          NaN    Magens Bay
# 1  St. George Village Botanical Garden          NaN  Frederiksted
#
#              State
# 0   Virgin Islands
# 1   Virgin Islands

# %%
utah= tables[34]
utah_df= pd.DataFrame(utah)
utah_df=utah_df.drop(columns='Image')
utah_df['State']='Utah'
utah_df
# Out:
#                                                 Name  \
# 0  Brigham Young University Arboretum (Harrison A...
# 1                           Conservation Garden Park
# 2                        International Peace Gardens
# 3                                 Petersen Arboretum
# 4                     Red Butte Garden and Arboretum
# 5                            Red Hills Desert Garden
# 6                Robert L. Shepherd Desert Arboretum
# 7                            State Arboretum of Utah
# 8               Stein Eriksen Lodge Botanical Garden
# 9                              Utah Botanical Center
#
#                                     Affiliation            City State
# 0                      Brigham Young University           Provo  Utah
# 1      Jordan Valley Water Conservancy District     West Jordan  Utah
# 2                                           NaN  Salt Lake City  Utah
# 3                                           NaN          Alpine  Utah
# ...

# %%
vermont= tables[35]
vermont_df= pd.DataFrame(vermont)
vermont_df=vermont_df.drop(columns='Image')
vermont_df['State']='Vermont'
vermont_df
# Out:
#                                             Name  Affiliation        City  \
# 0  Vermont Experimental Cold-Hardy Cactus Garden          NaN  Middlebury
#
#      State
# 0  Vermont

# %%
virginia= tables[36]
virginia_df= pd.DataFrame(virginia)
virginia_df=virginia_df.drop(columns='Image')
virginia_df['State']= 'Virgina'
virginia_df
# Out:
#                                   Name  \
# 0                    Boxerwood Gardens
# 1      Joseph Bryan Park Azalea Garden
# 2           Edith J. Carrier Arboretum
# 3                 Chesapeake Arboretum
# 4                 Forest Lawn Cemetery
# 5        Lewis Ginter Botanical Garden
# 6                 Green Spring Gardens
# 7             Hahn Horticulture Garden
# 8                              Maymont
# 9         Meadowlark Botanical Gardens
# 10     Museum of the Shenandoah Valley
# 11            Norfolk Botanical Garden
# 12                 Oatlands Plantation
# 13                   Old City Cemetery
# 14                          River Farm
# 15       Ticonderoga Botanical Gardens
# 16                 Tidewater Arboretum
# 17  Orland E. White Research Arboretum
# 18       Williamsburg Botanical Garden
#
#                                           Affiliation            City    State
# 0                                                 NaN       Lexington  Virgina
# ...

# %%
west_virginia= tables[37]
west_virginia_df= pd.DataFrame(west_virginia)
west_virginia_df=west_virginia_df.drop(columns='Image')
west_virginia_df['State']= 'West Virginia'
west_virginia_df
# Out:
#                               Name                  Affiliation        City  \
# 0        Brooks Memorial Arboretum                          NaN   Hillsboro
# 1           Earl L. Core Arboretum     West Virginia University  Morgantown
# 2  Cranberry Glades Botanical Area  Monongahela National Forest  Mill Point
# 3        Sunshine Farm and Gardens                          NaN      Renick
# 4     West Virginia Botanic Garden                          NaN  Morgantown
#
#            State
# 0  West Virginia
# 1  West Virginia
# 2  West Virginia
# 3  West Virginia
# 4  West Virginia

# %%
wisconsin= tables[38]
wisconsin_df= pd.DataFrame(wisconsin)
wisconsin_df=wisconsin_df.drop(columns='Image')
wisconsin_df['State']= 'Wisconsin'
wisconsin_df
# Out:
#                                                  Name  \
# 0                           Boerner Botanical Gardens
# 1                           Cofrin Memorial Arboretum
# 2                           Foxfire Botanical Gardens
# 3                           Gardens of the Fox Cities
# 4                          Green Bay Botanical Garden
# 5               Jones Arboretum and Botanical Gardens
# 6                            Ledge View Nature Center
# 7            Mitchell Park Horticultural Conservatory
# 8                                         Norskedalen
# 9                           Olbrich Botanical Gardens
# 10                       Paine Art Center and Gardens
# 11                                     Rotary Gardens
# 12                                  Schmeekle Reserve
# 13          University of Wisconsin–Madison Arboretum
# 14  University of Wisconsin–Madison Botany Garden ...
#
#                 Affiliation           City      State
# ...

# %%
wyoming= tables[39]
wyoming_df= pd.DataFrame(wyoming)
wyoming_df=wyoming_df.drop(columns= 'Image')
wyoming_df['State']='Wyoming'
wyoming_df
# Out:
#                        Name  Affiliation      City    State
# 0  Cheyenne Botanic Gardens          NaN  Cheyenne  Wyoming

# %%
#MISSING STATES#
url2= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Alabama'
tables2 =pd.read_html(url2)

# %%
alabama= tables2[0]
alabama_table= pd.DataFrame(alabama)
alabama_table
# Out:
#                                         0        1      2  \
# 0                                    Name  Founded  Image
# 1           Aldridge Botanical Gardens[1]     2002    NaN
# 2            William Bartram Arboretum[2]     1984    NaN
# 3         Bellingrath Gardens and Home[3]     1932    NaN
# 4         Birmingham Botanical Gardens[4]     1963    NaN
# 5            Donald E. Davis Arboretum[5]     1977    NaN
# 6        Dothan Area Botanical Gardens[6]     1990    NaN
# 7          Huntsville Botanical Garden[7]     1988    NaN
# 8                 Jasmine Hill Gardens[8]     1928    NaN
# 9             Mobile Botanical Gardens[9]     1974    NaN
# 10  Noccalula Falls Botanical Gardens[10]      NaN    NaN
# 11          Troy University Arboretum[11]      NaN    NaN
# 12    University of Alabama Arboretum[12]     1958    NaN
#
#                        3           4  \
# 0                   Size   Admission
# 1       30 acres (12 ha)        Free
# ...

# %%
alabama_t2= alabama_table.rename(columns= {0:'Name', 1: 'Founded', 2 : 'Image', 3: 'Size', 4: 'Admission', 5: 'Affiliation', 6: 'City'})
alabama_t2.drop(alabama_t2.index[0])
alabama_df= alabama_t2.drop(alabama_t2.index[0])
alabama_df=alabama_df.drop(columns='Image')
alabama_df['State']='Alabama'
alabama_df
# Out:
#                                      Name Founded                  Size  \
# 1           Aldridge Botanical Gardens[1]    2002      30 acres (12 ha)
# 2            William Bartram Arboretum[2]    1984      30 acres (12 ha)
# 3         Bellingrath Gardens and Home[3]    1932      65 acres (26 ha)
# 4         Birmingham Botanical Gardens[4]    1963  67.5 acres (27.3 ha)
# 5            Donald E. Davis Arboretum[5]    1977     14 acres (5.7 ha)
# 6        Dothan Area Botanical Gardens[6]    1990      50 acres (20 ha)
# 7          Huntsville Botanical Garden[7]    1988     112 acres (45 ha)
# 8                 Jasmine Hill Gardens[8]    1928     20 acres (8.1 ha)
# 9             Mobile Botanical Gardens[9]    1974     100 acres (40 ha)
# 10  Noccalula Falls Botanical Gardens[10]     NaN      65 acres (26 ha)
# 11          Troy University Arboretum[11]     NaN      75 acres (30 ha)
# 12    University of Alabama Arboretum[12]    1958      60 acres (24 ha)
#
# ...

# %%
url3= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_California'
tables3 =pd.read_html(url3)

# %%
california= tables3[0]
california_df= pd.DataFrame(california)
california_df=california_df.drop(columns='Image')
california_df['State']='California'
california_df
# Out:
#                                                  Name  \
# 0                                  Alta Vista Gardens
# 1                                    Arlington Garden
# 2                                 Balboa Park Gardens
# 3                                Ruth Bancroft Garden
# 4                                        Blake Garden
# 5                     Luther Burbank Home and Gardens
# 6   California State University Northridge Botanic...
# 7                             Clovis Botanical Garden
# 8                             Chavez Ravine Arboretum
# 9                          Chico University Arboretum
# 10                     Conejo Valley Botanical Garden
# 11                            Conservatory of Flowers
# 12                                   Descanso Gardens
# 13                         Dunsmuir Botanical Gardens
# 14                                     Eddy Arboretum
# 15                            Edgewood Botanic Garden
# ...

# %%
url4= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Florida'
tables4= pd.read_html(url4)

# %%
florida= tables4[0]
florida_df= pd.DataFrame(florida)
florida_df=florida_df.drop(columns='Image')
florida_df['State']='Florida'
florida_df.head()
# Out:
#                                                 Name  \
# 0  American Orchid Society Visitor Center and Bot...
# 1     Arboretum of the University of Central Florida
# 2                                  Bok Tower Gardens
# 3                 Botanic Gardens at Kona Kai Resort
# 4                                    Cypress Gardens
#
#                      Affiliation          City    State
# 0        American Orchid Society  Delray Beach  Florida
# 1  University of Central Florida       Orlando  Florida
# 2                            NaN    Lake Wales  Florida
# 3                            NaN     Key Largo  Florida
# 4                            NaN  Winter Haven  Florida

# %%
url5= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Hawaii'
table5= pd.read_html(url5)

# %%
hawaii= table5[0]
hawaii_df= pd.DataFrame(hawaii)
hawaii_df=hawaii_df.drop(columns='Image')
hawaii_df['State']='Hawaii'
hawaii_df.head()
# Out:
#                                         Name  \
# 0                            Allerton Garden
# 1    Enchanting Floral Gardens of Kula, Maui
# 2                    Foster Botanical Garden
# 3  Amy B. H. Greenwell Ethnobotanical Garden
# 4           Hawaii Tropical Botanical Garden
#
#                           Affiliation          City   State
# 0  National Tropical Botanical Garden         Kauai  Hawaii
# 1                                 NaN          Kula  Hawaii
# 2          Honolulu Botanical Gardens      Honolulu  Hawaii
# 3                       Bishop Museum  Captain Cook  Hawaii
# 4                                 NaN     Pāpa'ikou  Hawaii

# %%
url6= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Illinois'
table6= pd.read_html(url6)

# %%
illinois= table6[0]
illinois_df= pd.DataFrame(illinois)
illinois_df=illinois_df.drop(columns='Image')
illinois_df['State']='Illinois'
illinois_df.head()
# Out:
#                         Name                   Affiliation          City  \
# 0  Anderson Japanese Gardens                           NaN      Rockford
# 1              Cantigny Park                           NaN       Wheaton
# 2     Chicago Botanic Garden                           NaN       Glencoe
# 3             Fell Arboretum     Illinois State University        Normal
# 4        The Gardens at SIUE  Southern Illinois University  Edwardsville
#
#       State
# 0  Illinois
# 1  Illinois
# 2  Illinois
# 3  Illinois
# 4  Illinois

# %%
url7= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Massachusetts'
table7= pd.read_html(url7)

# %%
massachusetts= table7[0]
massachusetts_table= pd.DataFrame(massachusetts)
massachusetts_df= massachusetts_table.drop(massachusetts_table.iloc[:, 4:10], axis = 1)
massachusetts_df=massachusetts_df.drop(columns='Image')
massachusetts_df['State']= 'Massachusetts'
massachusetts_df.head()
# Out:
#                                   Name               Affiliation         City  \
# 0                     Arnold Arboretum        Harvard University       Boston
# 1                    Babcock Arboretum  Eastern Nazarene College       Quincy
# 2           Berkshire Botanical Garden                       NaN  Stockbridge
# 3                 Boston Public Garden                       NaN       Boston
# 4  The Botanic Garden of Smith College             Smith College  Northampton
#
#   Unnamed: 10          State
# 0         NaN  Massachusetts
# 1         NaN  Massachusetts
# 2         NaN  Massachusetts
# 3         NaN  Massachusetts
# 4         NaN  Massachusetts

# %%
url8='https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_New_Jersey'
table8= pd.read_html(url8)

# %%
new_jersey= table8[0]
new_jersey_df= pd.DataFrame(new_jersey)
new_jersey_df=new_jersey_df.drop(columns='Image')
new_jersey_df['State']='New Jersey'
new_jersey_df.head()
# Out:
#                                     Name                    Affiliation  \
# 0  Bamboo Brook Outdoor Education Center  Morris County Park Commission
# 1              Lewis W. Barton Arboretum                            NaN
# 2                 Leonard J. Buck Garden                            NaN
# 3      Sister Mary Grace Burns Arboretum      Georgian Court University
# 4    Colonial Park Arboretum and Gardens                            NaN
#
#                City       State
# 0  Chester Township  New Jersey
# 1           Medford  New Jersey
# 2         Far Hills  New Jersey
# 3          Lakewood  New Jersey
# 4    East Millstone  New Jersey

# %%
url9= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_New_York'
table9= pd.read_html(url9)

# %%
new_york= table9[0]
new_york_df= pd.DataFrame(new_york)
new_york_df=new_york_df.drop(columns='Image')
new_york_df['State']='New York'
new_york_df.head()
# Out:
#                                         Name   Affiliation  \
# 0                           Bailey Arboretum           NaN
# 1                     Bard College Arboretum  Bard College
# 2        Bayard Cutting Arboretum State Park           NaN
# 3                    Brooklyn Botanic Garden           NaN
# 4  Buffalo and Erie County Botanical Gardens           NaN
#
#                   City     State
# 0        Locust Valley  New York
# 1  Annandale-on-Hudson  New York
# 2          Great River  New York
# 3             Brooklyn  New York
# 4              Buffalo  New York

# %%
url10= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_North_Carolina'
table10= pd.read_html(url10)

# %%
north_carolina= table10[0]
north_carolina_df= pd.DataFrame(north_carolina)
north_carolina_df=north_carolina_df.drop(columns='Image')
north_carolina_df['State']= 'North Carolina'
north_carolina_df.head()
# Out:
#                              Name                   Affiliation          City  \
# 0                  Airlie Gardens                           NaN    Wilmington
# 1                 Barred Owl Bend                           NaN     Pittsboro
# 2                  The Bog Garden                           NaN    Greensboro
# 3  Botanical Gardens at Asheville  University of North Carolina     Asheville
# 4      Cape Fear Botanical Garden                           NaN  Fayetteville
#
#             State
# 0  North Carolina
# 1  North Carolina
# 2  North Carolina
# 3  North Carolina
# 4  North Carolina

# %%
url11= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Ohio'
table11= pd.read_html(url11)

# %%
ohio= table11[0]
ohio_df= pd.DataFrame(ohio)
ohio_df=ohio_df.drop(columns='Image')
ohio_df['State']='Ohio'
ohio_df.head()
# Out:
#                                   Name            Affiliation        City  \
# 0                   Chadwick Arboretum  Ohio State University    Columbus
# 1  Cincinnati Zoo and Botanical Garden                    NaN  Cincinnati
# 2           Cleveland Botanical Garden                    NaN   Cleveland
# 3  Cox Arboretum and Gardens MetroPark                    NaN      Dayton
# 4                      Dawes Arboretum                    NaN      Newark
#
#   State
# 0  Ohio
# 1  Ohio
# 2  Ohio
# 3  Ohio
# 4  Ohio

# %%
url12= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Oregon'
table12= pd.read_html(url12)

# %%
oregon= table12[0]
oregon_df= pd.DataFrame(oregon)
oregon_df=oregon_df.drop(columns='Image')
oregon_df['State']='Oregon'
oregon_df.head()
# Out:
#                                      Name Affiliation          City   State
# 0          Beekman Native Plant Arboretum         NaN  Jacksonville  Oregon
# 1                    Berry Botanic Garden         NaN      Portland  Oregon
# 2                     Bush's Pasture Park         NaN         Salem  Oregon
# 3     Crystal Springs Rhododendron Garden         NaN      Portland  Oregon
# 4  Elk Rock Gardens of the Bishop's Close         NaN     Dunthorpe  Oregon

# %%
url13= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Pennsylvania'
table13= pd.read_html(url13)

# %%
pennsylvania=table13[0]
pennsylvania_df= pd.DataFrame(pennsylvania)
pennsylvania_df=pennsylvania_df.drop(columns='Image')
pennsylvania_df['State']= 'Pennsylvania'
pennsylvania_df.head()
# Out:
#                                      Name                    Affiliation  \
# 0                        Ambler Arboretum              Temple University
# 1              American College Arboretum           The American College
# 2       Appleford/Parsons-Banks Arboretum                            NaN
# 3                 Arboretum at Penn State  Pennsylvania State University
# 4  Arboretum at the Reading Public Museum          Reading Public Museum
#
#             City         State
# 0         Ambler  Pennsylvania
# 1      Bryn Mawr  Pennsylvania
# 2      Villanova  Pennsylvania
# 3  State College  Pennsylvania
# 4        Reading  Pennsylvania

# %%
url14= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_South_Carolina'
table14= pd.read_html(url14)

# %%
south_carolina= table14[0]
south_carolina_df= pd.DataFrame(south_carolina)
south_carolina_df=south_carolina_df.drop(columns='Image')
south_carolina_df['State']='South Carolina'
south_carolina_df.head()
# Out:
#                                 Name                   Affiliation  \
# 0         W. Gordon Belser Arboretum  University of South Carolina
# 1                 Brookgreen Gardens                           NaN
# 2                    Cypress Gardens                           NaN
# 3  Furman University Japanese Garden             Furman University
# 4                     Kalmia Gardens                 Coker College
#
#              City           State
# 0        Columbia  South Carolina
# 1  Pawleys Island  South Carolina
# 2   Moncks Corner  South Carolina
# 3      Greenville  South Carolina
# 4      Hartsville  South Carolina

# %%
url15= 'https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Washington_(state)'
table15= pd.read_html(url15)

# %%
washington= table15[0]
washington_df= pd.DataFrame(washington)
washington_df=washington_df.drop(columns='Image')
washington_df['State']='Washington'
washington_df.head()
# Out:
#                                       Name Affiliation               City  \
# 0                Bellevue Botanical Garden         NaN           Bellevue
# 1                          Bloedel Reserve         NaN  Bainbridge Island
# 2             Bonhoeffer Botanical Gardens         NaN           Stanwood
# 3          Evergreen Arboretum and Gardens         NaN            Everett
# 4  Carl S. English, Jr., Botanical Gardens         NaN            Seattle
#
#         State
# 0  Washington
# 1  Washington
# 2  Washington
# 3  Washington
# 4  Washington

# %%
##WRITE TO MONGODB##
#Each state will be a collection#
#each collection has a list of botanical gardens#

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db= client.StatePlants_db
collection= db.items

# %%
db.California.insert_many(california_df.to_dict('records'))

# %%
db.Alabama.insert_many(alabama_df.to_dict('records'))

# %%
db.Alaska.insert_many(alaska_df.to_dict('records'))

# %%
db.Arizona.insert_many(arizona_df.to_dict('records'))

# %%
db.Arkansas.insert_many(arkansas_df.to_dict('records'))

# %%
db.Colorado.insert_many(colorado_df.to_dict('records'))

# %%
db.Connecticut.insert_many(connecticut_df.to_dict('records'))

# %%
db.Delaware.insert_many(delaware_df.to_dict('records'))

# %%
db.Florida.insert_many(florida_df.to_dict('records'))

# %%
db.Georgia.insert_many(georgia_df.to_dict('records'))

# %%
db.Hawaii.insert_many(hawaii_df.to_dict('records'))

# %%
db.Idaho.insert_many(idaho_df.to_dict('records'))

# %%
db.Illinois.insert_many(illinois_df.to_dict('records'))

# %%
db.Indiana.insert_many(indiana_df.to_dict('records'))

# %%
db.Iowa.insert_many(iowa_df.to_dict('records'))

# %%
db.Kansas.insert_many(kansas_df.to_dict('records'))

# %%
db.Kentucky.insert_many(kentucky_df.to_dict('records'))

# %%
db.Louisiana.insert_many(louisiana_df.to_dict('records'))

# %%
db.Maine.insert_many(maine_df.to_dict('records'))

# %%
db.Maryland.insert_many(maryland_df.to_dict('records'))

# %%
db.Massachusetts.insert_many(massachusetts_df.to_dict('records'))

# %%
db.Michigan.insert_many(michigan_df.to_dict('records'))

# %%
db.Minnesota.insert_many(minnesota_df.to_dict('records'))

# %%
db.Mississippi.insert_many(mississippi_df.to_dict('records'))

# %%
db.Missouri.insert_many(missouri_df.to_dict('records'))

# %%
db.Montana.insert_many(montana_df.to_dict('records'))

# %%
db.Nebraska.insert_many(nebraska_df.to_dict('records'))

# %%
db.Nevada.insert_many(nevada_df.to_dict('records'))

# %%
db.New_Hampshire.insert_many(new_hampshire_df.to_dict('records'))

# %%
db.New_Jersey.insert_many(new_jersey_df.to_dict('records'))

# %%
db.New_Mexico.insert_many(new_mexico_df.to_dict('records'))

# %%
db.New_York.insert_many(new_york_df.to_dict('records'))

# %%
db.North_Carolina.insert_many(north_carolina_df.to_dict('records'))

# %%
db.North_Dakota.insert_many(north_dakota_df.to_dict('records'))

# %%
db.Ohio.insert_many(ohio_df.to_dict('records'))

# %%
db.Oklahoma.insert_many(oklahoma_df.to_dict('records'))

# %%
db.Oregon.insert_many(oregon_df.to_dict('records'))

# %%
db.Pennsylvania.insert_many(pennsylvania_df.to_dict('records'))

# %%
db.Rhode_Island.insert_many(rhode_island_df.to_dict('records'))

# %%
db.South_Carolina.insert_many(south_carolina_df.to_dict('records'))

# %%
db.South_Dakota.insert_many(south_dakota_df.to_dict('records'))

# %%
db.Tennessee.insert_many(tennessee_df.to_dict('records'))

# %%
db.Texas.insert_many(texas_df.to_dict('records'))

# %%
db.Utah.insert_many(utah_df.to_dict('records'))

# %%
db.Vermont.insert_many(vermont_df.to_dict('records'))

# %%
db.Virginia.insert_many(virginia_df.to_dict('records'))

# %%
db.Washington.insert_many(washington_df.to_dict('records'))

# %%
db.West_Virginia.insert_many(west_virginia_df.to_dict('records'))

# %%
db.Wisconsin.insert_many(wisconsin_df.to_dict('records'))

# %%
db.Wyoming.insert_many(wyoming_df.to_dict('records'))

# %%
db.US_Virgin_Islands.insert_many(virgin_islands_df.to_dict('records'))

# %%
db.Guam.insert_many(guam_df.to_dict('records'))

# %%
db.Puerto_Rico.insert_many(puerto_rico_df.to_dict('records'))

# %%
db.District_of_Columbia.insert_many(district_of_columbia_df.to_dict('records'))

# %%
#See list of collections#
print(db.list_collection_names())
# Out:
# ['Oklahoma', 'Connecticut', 'North_Carolina', 'California', 'Illinois', 'Louisiana', 'US_Virgin_Islands', 'Oregon', 'South_Dakota', 'Guam', 'New_Mexico', 'Kentucky', 'Florida', 'Missouri', 'Rhode_Island', 'Maryland', 'Minnesota', 'Hawaii', 'Nevada', 'New_York', 'West_Virginia', 'Idaho', 'Washington', 'Nebraska', 'Iowa', 'Georgia', 'Pennsylvania', 'Vermont', 'Indiana', 'Massachusetts', 'Utah', 'South_Carolina', 'Alaska', 'Kansas', 'Delaware', 'Michigan', 'Wyoming', 'Tennessee', 'Virginia', 'Arkansas', 'North_Dakota', 'Montana', 'District_of_Columbia', 'Texas', 'New_Hampshire', 'Ohio', 'Wisconsin', 'Arizona', 'Colorado', 'Alabama', 'Maine', 'New_Jersey', 'Mississippi', 'Puerto_Rico']

# %%
#see list of documents in Kansas collection#
kansas= db.Kansas.find()
print(list(kansas))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#number of documents in Kansas Collection#
kansas_docs= db.Kansas.estimated_document_count()
kansas_docs
# Out:
# 10837

# %%
list(db.Kansas.find('Name'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-b525e8b34cca> in <module>
# ----> 1 list(db.Kansas.find('Name'))
#
# //anaconda3/lib/python3.7/site-packages/pymongo/collection.py in find(self, *args, **kwargs)
#    1458
#    1459         """
# -> 1460         return Cursor(self, *args, **kwargs)
#    1461
#    1462     def find_raw_batches(self, *args, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/pymongo/cursor.py in __init__(self, collection, filter, projection, skip, limit, no_cursor_timeout, cursor_type, sort, allow_partial_results, oplog_replay, modifiers, batch_size, manipulate, collation, hint, max_scan, max_time_ms, max, min, return_key, show_record_id, snapshot, comment, session)
#     141             spec = {}
#     142
# --> 143         validate_is_mapping("filter", spec)
#     144         if not isinstance(skip, int):
# ...
