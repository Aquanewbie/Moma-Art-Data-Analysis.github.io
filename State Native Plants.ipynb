# %%
#Import Dependencies
import pandas as pd
import pymongo

#50 States
StateList = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
             'Florida','Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
             'Maine','Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi','Missouri', 'Montana',
             'Nebraska', 'Nevada','New_Hampshire', 'New_Jersey', 'New_Mexico', 'New_York', 'North_Carolina',
             'North_Dakota', 'Ohio', 'Oklahoma', 'Oregon','Pennsylvania', 'Rhode_Island', 'South_Carolina', 
             'South_Dakota', 'Tennessee', 'Texas',  'Utah',  'Vermont',  'Virginia','Washington',  'West_Virginia',
             'Wisconsin',  'Wyoming']
#Read CSVs through a for loop.
for i in StateList:
    #print(i)
    path = (f'{i}.csv')
    PlantList=pd.read_csv(path, encoding='utf-8')
    PlantList['State']=i

    #Extract Genus and Specie Name by taking First two Words from 'Scientific Name with Author'
    Scientificname=[]
    for x in PlantList['Scientific Name with Author']:
        name=x.split()[:2]
        Scientificname.append(name)
        
    #Create a Column with Scientific Name
    Scientificnamedf=pd.DataFrame(Scientificname, columns = ['Genus', 'Species'])
    Scientificnamedf['Scientific Name with Author']=PlantList['Scientific Name with Author']
    Scientificnamedf.head()
    
    #Merge Data Frames
    Compositedf=PlantList.merge(Scientificnamedf)
    
    #Name Dataframes Uniquely
    if i == 'Alabama':
       Alabamadf=Compositedf
    elif i == 'Alaska':
        Alaskadf=Compositedf
    elif i == 'Arizona':
        Arizonadf=Compositedf
    elif i == 'Arkansas':
        Arkansasdf=Compositedf
    elif i == 'California':
        Californiadf=Compositedf
    elif i == 'Colorado':
        Coloradodf=Compositedf
    elif i == 'Connecticut':
        Connecticutdf=Compositedf
    elif i == 'Delaware':
        Delawaredf=Compositedf
    elif i == 'Florida':
        Floridadf=Compositedf
    elif i == 'Georgia':
        Georgiadf=Compositedf
    elif i == 'Hawaii':
        Hawaiidf=Compositedf
    elif i == 'Idaho':
        Idahodf=Compositedf
    elif i == 'Illinois':
        Illinoisdf=Compositedf
    elif i == 'Indiana':
        Indianadf=Compositedf
    elif i == 'Iowa':
        Iowadf=Compositedf
    elif i == 'Kansas':
        Kansasdf=Compositedf
    elif i == 'Kentucky':
        Kentuckydf=Compositedf
    elif i == 'Louisiana':
        Louisianadf=Compositedf
    elif i == 'Maine':
        Mainedf=Compositedf
    elif i == 'Maryland':
        Marylanddf=Compositedf
    elif i == 'Massachusetts':
        Massachusettsdf=Compositedf
    elif i == 'Minnesota':
        Minnesotadf=Compositedf      
    elif i == 'Mississippi':
        Mississippidf=Compositedf
    elif i == 'Missouri':
        Missouridf=Compositedf
    elif i == 'Montana':
        Montanadf=Compositedf
    elif i == 'Nebraska':
        Nebraskadf=Compositedf
    elif i == 'Nevada':
        Nevadadf=Compositedf       
    elif i == 'New_Hampshire':
        New_Hampshiredf=Compositedf
    elif i == 'New_Jersey':
        New_Jerseydf=Compositedf
    elif i == 'New_Mexico':
        New_Mexicodf=Compositedf
    elif i == 'Nebraska':
        Nebraskadf=Compositedf
    elif i == 'New_York':
        New_Yorkdf=Compositedf      
    elif i == 'North_Carolina':
        North_Carolinadf=Compositedf        
    elif i == 'North_Dakota':
        North_Dakotadf=Compositedf
    elif i == 'Ohio':
        Ohiodf=Compositedf
    elif i == 'Oklahoma':
        Oklahomadf=Compositedf
    elif i == 'Oregon':
        Oregondf=Compositedf        
    elif i == 'Pennsylvania':
        Pennsylvaniadf=Compositedf     
    elif i == 'Rhode_Island':
        Rhode_Islanddf=Compositedf
    elif i == 'South_Carolina':
        South_Carolinadf=Compositedf
    elif i == 'South_Dakota':
        South_Dakotadf=Compositedf
    elif i == 'Tennessee':
        Tennesseedf=Compositedf
    elif i == 'Texas':
        Texasdf=Compositedf
    elif i == 'Utah':
        Utahdf=Compositedf
    elif i == 'Vermont':
        Vermontdf=Compositedf
    elif i == 'Virginia':
        Virginiadf=Compositedf
    elif i == 'South_Dakota':
        South_Dakotadf=Compositedf
    elif i == 'Tennessee':
        Tennesseedf=Compositedf
    elif i == 'Texas':
        Texasdf=Compositedf
    elif i == 'Utah':
        Utahdf=Compositedf
    elif i == 'Vermont':
        Vermontdf=Compositedf
    elif i == 'Virginia':
        Virginiadf=Compositedf
    elif i == 'Washington':
        South_Dakotadf=Compositedf
    elif i == 'West_Virginia':
        West_Virginiadf=Compositedf
    elif i == 'Wisconsin':
        Wisconsindf=Compositedf
    elif i == 'Wyoming':
        Wyomingdf=Compositedf
    else:
        print("God Bless America, I'm Done")
# Out:
# God Bless America, I'm Done

# %%
#Connect to Mongo and Define a Database
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.StatePlants_db
collection = db.items

# %%
#Convert Dataframes to Dictionaries and Insert into Mongo Database
db.Alabama.insert_many(Alabamadf.to_dict('record'))
db.Alaska.insert_many(Alaskadf.to_dict('record'))
db.Arizona.insert_many(Arizonadf.to_dict('record'))
db.Arkansas.insert_many(Arkansasdf.to_dict('record'))
db.California.insert_many(Californiadf.to_dict('record'))
db.Colorado.insert_many(Coloradodf.to_dict('record'))
db.Connecticut.insert_many(Connecticutdf.to_dict('record'))
db.Delaware.insert_many(Delawaredf.to_dict('record'))
db.Florida.insert_many(Floridadf.to_dict('record'))
db.Georgia.insert_many(Georgiadf.to_dict('record'))
db.Hawaii.insert_many(Hawaiidf.to_dict('record'))
db.Idaho.insert_many(Idahodf.to_dict('record'))
db.Illinois.insert_many(Illinoisdf.to_dict('record'))
db.Indiana.insert_many(Indianadf.to_dict('record'))
db.Iowa.insert_many(Iowadf.to_dict('record'))
db.Indiana.insert_many(Indianadf.to_dict('record'))
db.Kansas.insert_many(Kansasdf.to_dict('record'))
db.Kentucky.insert_many(Kentuckydf.to_dict('record'))
db.Nebraska.insert_many(Nebraskadf.to_dict('record'))
db.Nevada.insert_many(Nevadadf.to_dict('record'))
db.New_Hampshire.insert_many(New_Hampshiredf.to_dict('record'))
db.New_Jersey.insert_many(New_Jerseydf.to_dict('record'))
db.New_Mexico.insert_many(New_Mexicodf.to_dict('record'))
db.New_York.insert_many(New_Yorkdf.to_dict('record'))
db.North_Carolina.insert_many(North_Carolinadf.to_dict('record'))
db.North_Dakota.insert_many(North_Dakotadf.to_dict('record'))
db.Ohio.insert_many(Ohiodf.to_dict('record'))
db.Oklahoma.insert_many(Oklahomadf.to_dict('record'))
db.Oregon.insert_many(Oregondf.to_dict('record'))
db.Pennsylvania.insert_many(Pennsylvaniadf.to_dict('record'))
db.Rhode_Island.insert_many(Rhode_Islanddf.to_dict('record'))
db.South_Carolina.insert_many(South_Carolinadf.to_dict('record'))
db.South_Dakota.insert_many(South_Dakotadf.to_dict('record'))
db.Tennessee.insert_many(Tennesseedf.to_dict('record'))
db.Texas.insert_many(Texasdf.to_dict('record'))
db.Utah.insert_many(Utahdf.to_dict('record'))
db.Vermont.insert_many(Vermontdf.to_dict('record'))
db.Virginia.insert_many(Virginiadf.to_dict('record'))
db.Washington.insert_many(Washingtondf.to_dict('record'))
db.West_Virginia.insert_many(West_Virginiadf.to_dict('record'))
db.Wisconsin.insert_many(Wisconsindf.to_dict('record'))
db.Wyoming.insert_many(Wyomingdf.to_dict('record'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-90a9a37a1c03> in <module>
#      38 db.Virginia.insert_many(Virginiadf.to_dict('record'))
#      39 db.Washington.insert_many(Washingtondf.to_dict('record'))
# ---> 40 db.West_Virginia.insert_many(West_Virginiadf.to_dict('record'))
#      41 db.Wisconsin.insert_many(Wisconsindf.to_dict('record'))
#      42 db.Wyoming.insert_many(Wyomingdf.to_dict('record'))
#
# NameError: name 'West_Virginiadf' is not defined
